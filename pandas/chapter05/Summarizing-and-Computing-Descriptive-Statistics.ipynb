# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Summarizing and Computing Descriptive Statistics

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
                    [np.nan, np.nan], [0.75, -1.3]],
                    index=["a", "b", "c", "d"],
                    columns=["one", "two"])
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
# return sum of each column's values
df.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
# returns sums across the columns
df.sum(axis="columns")
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
# any NA value in a row or column names the corresponding result NA
df.sum(axis="index", skipna=False)
# Out:
# one   NaN
# two   NaN
# dtype: float64

# %%
df.sum(axis="columns", skipna=False)
# Out:
# a     NaN
# b    2.60
# c     NaN
# d   -0.55
# dtype: float64

# %%
# produce multiple summary statistics in one shot
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
# nonnumeric data - describe method returns alternative summary statistics
obj = pd.Series(["a", "a", "b", "c"] * 4)
obj.describe()
# Out:
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %% [markdown]
# ### Unique Values, Value Counts, and Membership

# %%
obj = pd.Series(["c", "a", "d", "a", "a", "b", "b", "c", "c"])
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: str

# %%
# gives you an array of the unique values in a Series
uniques = obj.unique()
uniques
# Out:
# <ArrowStringArray>
# ['c', 'a', 'd', 'b']
# Length: 4, dtype: str

# %%
# value_counts computes a Series containing value frequencies
obj.value_counts()
# Out:
# c    3
# a    3
# b    2
# d    1
# Name: count, dtype: int64

# %%
# a vectorized set membership check
mask = obj.isin(["b", "c"])
mask
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
# can be usefuk in filtering a dataset down to a subset of values
obj[mask]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: str
